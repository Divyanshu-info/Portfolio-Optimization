# %%
import yfinance as yf
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import LSTM, Flatten, Dense
from tensorflow.keras.models import Sequential
import tensorflow.keras.backend as K
from tensorflow.keras.layers.experimental import preprocessing
from risk_model import Model
from datetime import datetime
import riskfolio as rp
from pandas_datareader import data as pdr
# %matplotlib inline

from absl import logging
tf.get_logger().setLevel('ERROR')

float_formatter = "{:.4f}".format
np.set_printoptions(formatter={'float_kind':float_formatter})
tf.random.set_seed(123)

np.random.seed(123)
yf.pdr_override()  # <== that's all it takes :-)


very_small_float = 0.000000001
# Out:
# 2022-09-22 07:25:41.485939: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-22 07:25:41.679877: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-09-22 07:25:41.679909: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-09-22 07:25:41.712827: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-09-22 07:25:42.723656: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2022-09-22 07:25:42.723824: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2022-09-22 07:25:42.723844: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
from bt_testcode import backtest, DynRebalance, get_name, plotAllocation, getStatistic, calc_portfolio_values
from bt_testcode import plotPortfolioReturns, get_portfolio_values

# %% [markdown]
# # Test Model

# %%
ticker = """AXISBANK.NS	BPCL.NS	BRITANNIA.NS	CIPLA.NS	DRREDDY.NS	EICHERMOT.NS	GAIL.NS	HDFCBANK.NS	HINDALCO.NS	HINDUNILVR.NS	INFY.NS	IOC.NS	ITC.NS	M&M.NS	MARICO.NS	ONGC.NS	RELIANCE.NS	SAIL.NS	SBIN.NS	SIEMENS.NS	SUNPHARMA.NS	TATACONSUM.NS	TATAMOTORS.NS	TATAPOWER.NS	TATASTEEL.NS	TITAN.NS VEDL.NS	WIPRO.NS""".split()
benchmark_index = "^BSESN"
history_range = {'start': datetime(2000, 1, 1), 
                 'end': datetime(2022, 7, 31)}

stock = pdr.DataReader(ticker, 
                start=history_range['start'],
                end=history_range['end'],
                data_source='yahoo')
# Out:
# [*********************100%***********************]  28 of 28 completed

# %%
stock_close = stock.iloc[:]['Close'].fillna(very_small_float)
stock_close.head()
# Out:
#             AXISBANK.NS    BPCL.NS  BRITANNIA.NS    CIPLA.NS  DRREDDY.NS  \
# Date
# 2000-01-03         5.18  33.270832     75.690002  116.587997  377.062500
# 2000-01-04         5.38  30.875000     75.455002  117.220001  407.237488
# 2000-01-05         5.24  29.995832     73.529999  114.804001  392.012512
# 2000-01-06         5.11  31.691666     78.565002  108.468002  415.387512
# 2000-01-07         4.86  31.654165     84.849998   99.804001  382.274994
#
#             EICHERMOT.NS   GAIL.NS  HDFCBANK.NS  HINDALCO.NS  HINDUNILVR.NS  \
# Date
# 2000-01-03         4.885  8.587504    17.000000    73.833130     230.755005
# 2000-01-04         5.140  8.293754    17.379999    76.633423     228.104996
# 2000-01-05         5.555  7.900003    16.695000    82.761711     219.990005
# 2000-01-06         6.000  8.118754    16.830000    89.238976     228.820007
# 2000-01-07         6.465  7.831253    16.834999    93.196831     241.294998
#
#             ...    SBIN.NS  SIEMENS.NS  SUNPHARMA.NS  TATACONSUM.NS  \
# Date        ...
# 2000-01-03  ...  22.988886   54.494999     14.214153      56.450001
# 2000-01-04  ...  24.446625   54.654999     14.023603      55.090000
# 2000-01-05  ...  23.441774   52.250000     13.531350      52.794998
# 2000-01-06  ...  24.625893   53.000000     13.518182      54.560001
# 2000-01-07  ...  25.786425   48.779999     12.436851      58.910000
#
#             TATAMOTORS.NS  TATAPOWER.NS  TATASTEEL.NS  TITAN.NS  VEDL.NS  \
# Date
# 2000-01-03      41.535931      7.406506      8.559305    7.7850  2.90875
# 2000-01-04      39.897491      7.420981      8.466666    7.3700  2.86750
# 2000-01-05      40.865227      7.565734      8.789500    6.9200  2.85000
# 2000-01-06      42.561157      7.802163      9.446396    7.4750  2.98250
# 2000-01-07      45.972179      7.787688      9.654133    7.3175  2.91250
#
#               WIPRO.NS
# Date
# 2000-01-03  102.157501
# 2000-01-04  110.330627
# 2000-01-05  112.128754
# 2000-01-06  109.959381
# 2000-01-07  101.163757
#
# [5 rows x 28 columns]

# %%
import matplotlib.pyplot as plt
rnd = 8
tf.random.set_seed(rnd)
np.random.seed(rnd)

param={}
param ={'model_params':
    {'model_n':'LSTM',
    'epochs':1000}}

m = Model()
alloc = m.get_allocations(stock_close.values, **param['model_params'])
print(alloc)
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 3s 3s/step - loss: -0.0351
# Epoch 2/1000
# 1/1 [==============================] - 1s 960ms/step - loss: -0.0394
# Epoch 3/1000
# 1/1 [==============================] - 1s 1s/step - loss: -0.0453
# Epoch 4/1000
# 1/1 [==============================] - 1s 1s/step - loss: -0.0496
# Epoch 5/1000
# 1/1 [==============================] - 1s 1s/step - loss: -0.0554
# Epoch 6/1000
# 1/1 [==============================] - 1s 928ms/step - loss: -0.0610
# Epoch 7/1000
# 1/1 [==============================] - 1s 945ms/step - loss: -0.0652
# Epoch 8/1000
# 1/1 [==============================] - 1s 1s/step - loss: -0.0677
# Epoch 9/1000
# 1/1 [==============================] - 1s 1s/step - loss: -0.0688
# Epoch 10/1000
# 1/1 [==============================] - 1s 1s/step - loss: -0.0697
# Epoch 11/1000
# 1/1 [==============================] - 1s 1s/step - loss: -0.0706
# Epoch 12/1000
# 1/1 [==============================] - 1s 999ms/step - loss: -0.0709
# Epoch 13/1000
# 1/1 [==============================] - 2s 2s/step - loss: -0.0709
# Epoch 14/1000
# 1/1 [==============================] - 2s 2s/step - loss: -0.0710
# Epoch 15/1000
# 1/1 [==============================] - 2s 2s/step - loss: -0.0711
# Epoch 16/1000
# 1/1 [==============================] - 3s 3s/step - loss: -0.0711
# Epoch 17/1000
# 1/1 [==============================] - 2s 2s/step - loss: -0.0711
# Epoch 18/1000
# 1/1 [==============================] - 1s 1s/step - loss: -0.0711
# Epoch 19/1000
# 1/1 [==============================] - 1s 1s/step - loss: -0.0712
# Epoch 20/1000
# 1/1 [==============================] - 1s 1s/step - loss: -0.0712
# Epoch 21/1000
# 1/1 [==============================] - 2s 2s/step - loss: -0.0712
# Epoch 22/1000
# 1/1 [==============================] - 3s 3s/step - loss: -0.0713
# Epoch 23/1000
# 1/1 [==============================] - 2s 2s/step - loss: -0.0713
# Epoch 24/1000
# 1/1 [==============================] - 1s 1s/step - loss: -0.0713
# Epoch 25/1000
# 1/1 [==============================] - 1s 1s/step - loss: -0.0713
# Epoch 26/1000
# 1/1 [==============================] - 1s 1s/step - loss: -0.0713
# Epoch 27/1000
# 1/1 [==============================] - 2s 2s/step - loss: -0.0713
# Epoch 28/1000
# 1/1 [==============================] - 2s 2s/step - loss: -0.0713
# Epoch 29/1000
# 1/1 [==============================] - 1s 1s/step - loss: -0.0714
# Epoch 30/1000
# 1/1 [==============================] - 1s 990ms/step - loss: -0.0714
# Epoch 31/1000
# 1/1 [==============================] - 1s 967ms/step - loss: -0.0714
# [0.0001 0.0000 0.0001 0.0000 0.0000 0.0000 0.0000 0.2724 0.0004 0.0001
#  0.0000 0.0000 0.0002 0.0000 0.2877 0.0000 0.0001 0.0003 0.0001 0.0132
#  0.2131 0.0000 0.0003 0.0000 0.0002 0.2113 0.0003 0.0001]

# %%
df = pd.DataFrame(alloc, index=ticker)
ax = rp.plot_pie(w=df, title='LSTM Asset Allocation', others=0.05, nrow=25, cmap="tab20",
                 height=6, width=10, ax=None)
# Out:
# /workspace/.pyenv_mirror/user/current/lib/python3.8/site-packages/riskfolio/PlotFunctions.py:569: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sizes2 = sizes2.append(item)

# %%
Y = stock_close
display(Y.head())
port = rp.Portfolio(returns=Y)
method_mu = 'hist'
# Method to estimate covariance matrix based on historical data.
method_cov = 'hist'

port.assets_stats(method_mu=method_mu, method_cov=method_cov, d=0.94)
fig = plt.figure()
fig = fig.add_axes()
ax = rp.plot_risk_con(w=df, cov=port.cov, returns=Y, rm='MV',
                      rf=0, alpha=0.05, color="tab:blue", height=6,
                      width=10, t_factor=252, ax=fig)
# Out:
#             AXISBANK.NS    BPCL.NS  BRITANNIA.NS    CIPLA.NS  DRREDDY.NS  \
# Date
# 2000-01-03         5.18  33.270832     75.690002  116.587997  377.062500
# 2000-01-04         5.38  30.875000     75.455002  117.220001  407.237488
# 2000-01-05         5.24  29.995832     73.529999  114.804001  392.012512
# 2000-01-06         5.11  31.691666     78.565002  108.468002  415.387512
# 2000-01-07         4.86  31.654165     84.849998   99.804001  382.274994
#
#             EICHERMOT.NS   GAIL.NS  HDFCBANK.NS  HINDALCO.NS  HINDUNILVR.NS  \
# Date
# 2000-01-03         4.885  8.587504    17.000000    73.833130     230.755005
# 2000-01-04         5.140  8.293754    17.379999    76.633423     228.104996
# 2000-01-05         5.555  7.900003    16.695000    82.761711     219.990005
# 2000-01-06         6.000  8.118754    16.830000    89.238976     228.820007
# 2000-01-07         6.465  7.831253    16.834999    93.196831     241.294998
#
#             ...    SBIN.NS  SIEMENS.NS  SUNPHARMA.NS  TATACONSUM.NS  \
# Date        ...
# 2000-01-03  ...  22.988886   54.494999     14.214153      56.450001
# 2000-01-04  ...  24.446625   54.654999     14.023603      55.090000
# 2000-01-05  ...  23.441774   52.250000     13.531350      52.794998
# 2000-01-06  ...  24.625893   53.000000     13.518182      54.560001
# 2000-01-07  ...  25.786425   48.779999     12.436851      58.910000
#
#             TATAMOTORS.NS  TATAPOWER.NS  TATASTEEL.NS  TITAN.NS  VEDL.NS  \
# Date
# 2000-01-03      41.535931      7.406506      8.559305    7.7850  2.90875
# 2000-01-04      39.897491      7.420981      8.466666    7.3700  2.86750
# 2000-01-05      40.865227      7.565734      8.789500    6.9200  2.85000
# 2000-01-06      42.561157      7.802163      9.446396    7.4750  2.98250
# 2000-01-07      45.972179      7.787688      9.654133    7.3175  2.91250
#
#               WIPRO.NS
# Date
# 2000-01-03  102.157501
# 2000-01-04  110.330627
# 2000-01-05  112.128754
# 2000-01-06  109.959381
# 2000-01-07  101.163757
#
# [5 rows x 28 columns]
# /workspace/.pyenv_mirror/user/current/lib/python3.8/site-packages/riskfolio/PlotFunctions.py:1127: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %%
cagr_graph = rp.plot_series(returns=Y, w=df, cmap='tab20', height=6, width=10,
                            ax=np.array([0, 0, 1, 1]))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [8], line 1
# ----> 1 cagr_graph = rp.plot_series(returns=Y, w=df, cmap='tab20', height=6, width=10,
#       2                             ax=np.array([0, 0, 1, 1]))
#
# File /workspace/.pyenv_mirror/user/current/lib/python3.8/site-packages/riskfolio/PlotFunctions.py:149, in plot_series(returns, w, cmap, height, width, ax)
#     147     fig.set_figheight(height)
#     148 else:
# --> 149     fig = ax.get_figure()
#     151 ax.grid(linestyle=":")
#     152 title = "Historical Compounded Cumulative Returns"
#
# AttributeError: 'numpy.ndarray' object has no attribute 'get_figure'

# %%
calc_portfolio_values(alloc, stock_close)
# Out:
# portfolio_returns: 5.6277
# std: 0.0140
# sharpe: 0.0711

# %%
config_cerebro = {
    'assets': ticker,
    #'assets':['SPY', 'TLT', 'GLD', 'BA', 'SLV', 'WYNN','MO', 'AEE', 'AIG', 'WY'],
    'benchmark': benchmark_index,
    'startd': history_range['start'],
    'endd': history_range['end'],
    'set_coc' : True,
    'set_coo' : False,
    'cash': 1000000.0,
    'stocks_df':None,
    'benchmark_df':None
}

params = {
    'DataCounter': 125,
    'RebalanceDay': 22,
    'reserveCash': 1000.0,
    'printlog': 0,
    'benchmarkUse': True,
    'resetModel':False, 
    'resetModelStep':4,
    'model':Model(),
    'model_params':{
        'model_n':'LSTM',
        'collectData':False,
        'epochs':1000}
}
d_res = {}
d_stat = {}

config_cerebro['stocks_df'] = pdr.DataReader(config_cerebro['assets'], 
                start=config_cerebro['startd'],
                end=config_cerebro['endd'],
                data_source='yahoo')
config_cerebro['benchmark_df'] = pdr.DataReader(config_cerebro['benchmark'], 
                start=config_cerebro['startd'],
                end=config_cerebro['endd'],
                data_source='yahoo')
# Out:
# [*********************100%***********************]  28 of 28 completed
# [*********************100%***********************]  1 of 1 completed

# %%
#tf.keras.utils.plot_model(m.getModel(), show_shapes=True)

# %%
import matplotlib.pyplot as plt
params['model'] = Model()
params['resetModel'] = False
# %matplotlib inline

plt.rcParams["figure.figsize"] = (10, 6)  # (w, h)
plt.plot()
d_stat[get_name(params)], d_res[get_name(params)], ah = backtest(config_cerebro, DynRebalance, m_name=get_name(params), plot=False, **params)
# Out:
# Starting Portfolio Value: 1000000.00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [16], line 8
#       6 plt.rcParams["figure.figsize"] = (10, 6)  # (w, h)
#       7 plt.plot()
# ----> 8 d_stat[get_name(params)], d_res[get_name(params)], ah = backtest(config_cerebro, DynRebalance, m_name=get_name(params), plot=False, **params)
#
# File /workspace/BTP/Final/bt_testcode.py:359, in backtest(cfg, strategy, plot, m_name, **kwargs)
#     357 cerebro.broker.setcash(cfg['cash'])
#     358 print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())
# --> 359 thestrats = cerebro.run()
#     360 thestrat = thestrats[0]
#     361 print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())
#
# File /workspace/.pyenv_mirror/user/current/lib/python3.8/site-packages/backtrader/cerebro.py:1127, in Cerebro.run(self, **kwargs)
#    1123 if not self._dooptimize or self.p.maxcpus == 1:
#    1124     # If no optimmization is wished ... or 1 core is to be used
#    1125     # let's skip process "spawning"
#    1126     for iterstrat in iterstrats:
# -> 1127         runstrat = self.runstrategies(iterstrat)
#    1128         self.runstrats.append(runstrat)
#    1129         if self._dooptimize:
#
# File /workspace/.pyenv_mirror/user/current/lib/python3.8/site-packages/backtrader/cerebro.py:1212, in Cerebro.runstrategies(self, iterstrat, predata)
#    1210         data._start()
#    1211         if self._dopreload:
# -> 1212             data.preload()
#    1214 for stratcls, sargs, skwargs in iterstrat:
#    1215     sargs = self.datas + list(sargs)
#
# File /workspace/.pyenv_mirror/user/current/lib/python3.8/site-packages/backtrader/feed.py:438, in AbstractDataBase.preload(self)
#     437 def preload(self):
# --> 438     while self.load():
#     439         pass
#     441     self._last()
#
# File /workspace/.pyenv_mirror/user/current/lib/python3.8/site-packages/backtrader/feed.py:479, in AbstractDataBase.load(self)
#     476     return True
#     478 if not self._fromstack(stash=True):
# --> 479     _loadret = self._load()
#     480     if not _loadret:  # no bar use force to make sure in exactbars
#     481         # the pointer is undone this covers especially (but not
#     482         # uniquely) the case in which the last bar has been seen
#     483         # and a backwards would ruin pointer accounting in the
#     484         # "stop" method of the strategy
#     485         self.backwards(force=True)  # undo data pointer
#
# File /workspace/.pyenv_mirror/user/current/lib/python3.8/site-packages/backtrader/feeds/pandafeed.py:255, in PandasData._load(self)
#     252     line = getattr(self.lines, datafield)
#     254     # indexing for pandas: 1st is colum, then row
# --> 255     line[0] = self.p.dataname.iloc[self._idx, colindex]
#     257 # datetime conversion
#     258 coldtime = self._colmapping['datetime']
#
# File /workspace/.pyenv_mirror/user/current/lib/python3.8/site-packages/pandas/core/indexing.py:960, in _LocationIndexer.__getitem__(self, key)
#     958     key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#     959     if self._is_scalar_access(key):
# --> 960         return self.obj._get_value(*key, takeable=self._takeable)
#     961     return self._getitem_tuple(key)
#     962 else:
#     963     # we by definition only have the 0th axis
#
# File /workspace/.pyenv_mirror/user/current/lib/python3.8/site-packages/pandas/core/frame.py:3612, in DataFrame._get_value(self, index, col, takeable)
#    3593 """
#    3594 Quickly retrieve single value at passed column and index.
#    3595
#    (...)
#    3609 `self.columns._index_as_unique`; Caller is responsible for checking.
#    3610 """
#    3611 if takeable:
# -> 3612     series = self._ixs(col, axis=1)
#    3613     return series._values[index]
#    3615 series = self._get_item_cache(col)
#
# File /workspace/.pyenv_mirror/user/current/lib/python3.8/site-packages/pandas/core/frame.py:3442, in DataFrame._ixs(self, i, axis)
#    3439 label = self.columns[i]
#    3441 col_mgr = self._mgr.iget(i)
# -> 3442 result = self._box_col_values(col_mgr, i)
#    3444 # this is a cached value, mark it so
#    3445 result._set_as_cached(label, self)
#
# File /workspace/.pyenv_mirror/user/current/lib/python3.8/site-packages/pandas/core/frame.py:3915, in DataFrame._box_col_values(self, values, loc)
#    3913 klass = self._constructor_sliced
#    3914 # We get index=self.index bc values is a SingleDataManager
# -> 3915 return klass(values, name=name, fastpath=True).__finalize__(self)
#
# File /workspace/.pyenv_mirror/user/current/lib/python3.8/site-packages/pandas/core/series.py:343, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     340 NDFrame.__init__(self, data)
#     341 if fastpath:
#     342     # e.g. from _box_col_values, skip validation of name
# --> 343     object.__setattr__(self, "_name", name)
#     344 else:
#     345     self.name = name
#
# KeyboardInterrupt:

# %%
display(d_stat[get_name(params)])
d_res[get_name(params)].plot()
# Out:
#            CAGR  Max_Drawdown  Sharp_Ratio         Value
# LSTM  20.070586     55.341729     0.966641  6.013514e+07
# <AxesSubplot: xlabel='data'>
